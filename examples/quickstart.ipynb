# %%
# Install the package if not already available
try:
    import owid.grapher
except ImportError:
    # %pip install owid-grapher-py

# %% [markdown]
# # OWID Grapher Python Demo
#
# This notebook demonstrates the `owid-grapher-py` package for creating interactive [Our World in Data](https://ourworldindata.org) charts in Jupyter notebooks.
#
# The API is inspired by Altair: wrap your DataFrame in a `Chart`, specify marks (`.mark_line()`, `.mark_bar()`, `.mark_scatter()`), and encode your data dimensions.

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
from owid.grapher import Chart

# %% [markdown]
# ## 1. Basic Examples with Sample Data
#
# Let's start with some simple examples using sample population data.

# %%
# Sample population data (in millions)
df = pd.DataFrame({
    'year': [2000, 2005, 2010, 2015, 2020] * 3,
    'country': ['Australia'] * 5 + ['New Zealand'] * 5 + ['Japan'] * 5,
    'population': [
        19.2, 20.4, 22.0, 23.8, 25.7,  # Australia
        3.9, 4.1, 4.4, 4.6, 5.1,       # New Zealand
        126.8, 127.8, 128.1, 127.1, 125.8  # Japan
    ]
})
df
# Out:
#     year      country  population
# 0   2000    Australia        19.2
# 1   2005    Australia        20.4
# 2   2010    Australia        22.0
# 3   2015    Australia        23.8
# 4   2020    Australia        25.7
# 5   2000  New Zealand         3.9
# 6   2005  New Zealand         4.1
# 7   2010  New Zealand         4.4
# 8   2015  New Zealand         4.6
# 9   2020  New Zealand         5.1
# 10  2000        Japan       126.8
# 11  2005        Japan       127.8
# 12  2010        Japan       128.1
# 13  2015        Japan       127.1
# 14  2020        Japan       125.8

# %% [markdown]
# ### Line Chart
#
# The most common chart type for time series data.

# %%
Chart(df).mark_line().encode(
    x='year',
    y='population',
    entity='country'
).label(title='Population Over Time')
# Out:
#         <div id="dkopwggwxcrdjewnwbej_wrapper" style="position: relative; width: 100%; height: 600px;">
#             <iframe id="dkopwggwxcrdjewnwbej" style="width: 100%; height: 100%; border: 0px none; pointer-events: none;"></iframe>
#         </div>
#         <script>
#             document.getElementById("dkopwggwxcrdjewnwbej").contentDocument.write(`
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta name="viewport" content="width=device-width, initial-scale=1" />
#     <link
#       href="https://fonts.googleapis.com/css?family=Lato:300,400,400i,700,700i|Playfair+Display:400,700&display=swap"
#       rel="stylesheet"
#     />
#     <link
#       rel="stylesheet"
#       href="https://expose-grapher-state.owid.pages.dev/assets/owid.css"
#     />
#     <style>
#       body { margin: 0; padding: 0; }
#       figure { width: 100%; height: 100%; margin: 0; }
#       .error { color: red; padding: 20px; background: #fee; border-radius: 5px; }
#       /* Hide UI elements for cleaner notebook display */
#       .grapher-share-button, .shareMenuOuter, .GrapherShareMenu,
#       a[data-track-note="chart_click_explore"], .exploreDataButton,
#       .originUrl, .SourcesFooter, .SourcesFooterHTML,
#       .GrapherFooter__sourcesAndLicense { display: none !important; }
#     </style>
#   </head>
#   <body>
#     <figure id="grapher-container"></figure>
#     <script type="module" src="https://expose-grapher-state.owid.pages.dev/assets/owid.mjs"><\/script>
#     <script type="module">
#       await new Promise((resolve) => setTimeout(resolve, 500));
#
#       const { Grapher, GrapherState, OwidTable, React, createRoot } = window;
#       const container = document.getElementById("grapher-container");
#
#       if (!GrapherState || !OwidTable || !React || !createRoot) {
#         container.innerHTML = '<div class="error">Required exports not available. Check console.</div>';
#         throw new Error("Required exports not available");
#       }
#
#       const csvData = \`year,entityName,population
# 2000,Australia,19.2
# 2005,Australia,20.4
# 2010,Australia,22.0
# 2015,Australia,23.8
# 2020,Australia,25.7
# 2000,New Zealand,3.9
# 2005,New Zealand,4.1
# 2010,New Zealand,4.4
# 2015,New Zealand,4.6
# 2020,New Zealand,5.1
# 2000,Japan,126.8
# 2005,Japan,127.8
# 2010,Japan,128.1
# 2015,Japan,127.1
# 2020,Japan,125.8
# \`;
#       const columnDefs = [{"slug": "population", "type": "Numeric"}];
#       const table = new OwidTable(csvData, columnDefs);
#
#       const grapherState = new GrapherState({
#         table: table,
#         ...{"hideLogo": true, "selectedEntityNames": ["Australia", "New Zealand", "Japan"], "chartTypes": ["LineChart"], "ySlugs": "population", "title": "Population Over Time", "tab": "chart", "stackMode": "absolute", "hideRelativeToggle": true, "hideEntityControls": true, "matchingEntitiesOnly": false},
#         isConfigReady: true,
#         isDataReady: true,
#       });
#
#       const reactRoot = createRoot(container);
#       reactRoot.render(React.createElement(Grapher, { grapherState }));
#     <\/script>
#   </body>
# </html>
# `);
#             document.getElementById("dkopwggwxcrdjewnwbej").contentDocument.close();
#             // Enable interaction on click (wrapper captures click), disable on mouse leave
#             document.getElementById("dkopwggwxcrdjewnwbej_wrapper").addEventListener("click", function() {
#                 document.getElementById("dkopwggwxcrdjewnwbej").style.pointerEvents = "auto";
#             });
#             document.getElementById("dkopwggwxcrdjewnwbej").addEventListener("mouseleave", function() {
#                 this.style.pointerEvents = "none";
#             });
#         </script>

# %% [markdown]
# ### Bar Chart
#
# Good for comparing values at a single point in time.

# %%
# Latest year only for bar chart
df_2020 = df[df['year'] == 2020]

Chart(df_2020).mark_bar().encode(
    x='population',
    y='country'
).label(title='Population in 2020')
# Out:
#         <div id="jeonobihnuvzfjiwgbje_wrapper" style="position: relative; width: 100%; height: 600px;">
#             <iframe id="jeonobihnuvzfjiwgbje" style="width: 100%; height: 100%; border: 0px none; pointer-events: none;"></iframe>
#         </div>
#         <script>
#             document.getElementById("jeonobihnuvzfjiwgbje").contentDocument.write(`
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta name="viewport" content="width=device-width, initial-scale=1" />
#     <link
#       href="https://fonts.googleapis.com/css?family=Lato:300,400,400i,700,700i|Playfair+Display:400,700&display=swap"
#       rel="stylesheet"
#     />
#     <link
#       rel="stylesheet"
#       href="https://expose-grapher-state.owid.pages.dev/assets/owid.css"
#     />
#     <style>
#       body { margin: 0; padding: 0; }
#       figure { width: 100%; height: 100%; margin: 0; }
#       .error { color: red; padding: 20px; background: #fee; border-radius: 5px; }
#       /* Hide UI elements for cleaner notebook display */
#       .grapher-share-button, .shareMenuOuter, .GrapherShareMenu,
#       a[data-track-note="chart_click_explore"], .exploreDataButton,
#       .originUrl, .SourcesFooter, .SourcesFooterHTML,
#       .GrapherFooter__sourcesAndLicense { display: none !important; }
#     </style>
#   </head>
#   <body>
#     <figure id="grapher-container"></figure>
#     <script type="module" src="https://expose-grapher-state.owid.pages.dev/assets/owid.mjs"><\/script>
#     <script type="module">
#       await new Promise((resolve) => setTimeout(resolve, 500));
#
#       const { Grapher, GrapherState, OwidTable, React, createRoot } = window;
#       const container = document.getElementById("grapher-container");
#
#       if (!GrapherState || !OwidTable || !React || !createRoot) {
#         container.innerHTML = '<div class="error">Required exports not available. Check console.</div>';
#         throw new Error("Required exports not available");
#       }
#
#       const csvData = \`year,entityName,population
# 2020,Australia,25.7
# 2020,New Zealand,5.1
# 2020,Japan,125.8
# \`;
#       const columnDefs = [{"slug": "population", "type": "Numeric"}];
#       const table = new OwidTable(csvData, columnDefs);
#
#       const grapherState = new GrapherState({
#         table: table,
#         ...{"hideLogo": true, "selectedEntityNames": ["Australia", "New Zealand", "Japan"], "chartTypes": ["DiscreteBar"], "ySlugs": "population", "title": "Population in 2020", "tab": "chart", "stackMode": "absolute", "hideRelativeToggle": true, "hideEntityControls": true, "matchingEntitiesOnly": false},
#         isConfigReady: true,
#         isDataReady: true,
#       });
#
#       const reactRoot = createRoot(container);
#       reactRoot.render(React.createElement(Grapher, { grapherState }));
#     <\/script>
#   </body>
# </html>
# `);
#             document.getElementById("jeonobihnuvzfjiwgbje").contentDocument.close();
#             // Enable interaction on click (wrapper captures click), disable on mouse leave
#             document.getElementById("jeonobihnuvzfjiwgbje_wrapper").addEventListener("click", function() {
#                 document.getElementById("jeonobihnuvzfjiwgbje").style.pointerEvents = "auto";
#             });
#             document.getElementById("jeonobihnuvzfjiwgbje").addEventListener("mouseleave", function() {
#                 this.style.pointerEvents = "none";
#             });
#         </script>

# %% [markdown]
# ### Simple Scatter Plot
#
# For showing relationships between two variables.

# %%
# Create simple GDP vs Life Expectancy data
df_scatter = pd.DataFrame({
    'gdp_per_capita': [5000, 15000, 25000, 35000, 45000, 8000, 18000, 28000, 38000,
                       6000, 12000, 20000, 30000, 40000, 7000, 16000, 24000, 32000],
    'life_expectancy': [65, 72, 78, 81, 83, 68, 74, 79, 82,
                       66, 70, 76, 80, 81, 67, 73, 77, 80],
    'country': ['Australia'] * 6 + ['New Zealand'] * 6 + ['Japan'] * 6,
    'year': [2020, 2021, 2022, 2023, 2024, 2020] * 3
})

Chart(df_scatter).mark_scatter().encode(
    x='gdp_per_capita',
    y='life_expectancy',
    entity='country'
).label(
    title='GDP per Capita vs Life Expectancy',
    subtitle='Each point represents a different time period',
    source_desc='Sample data'
)
# Out:
#         <div id="bafgbbijfznowwbwukvl_wrapper" style="position: relative; width: 100%; height: 600px;">
#             <iframe id="bafgbbijfznowwbwukvl" style="width: 100%; height: 100%; border: 0px none; pointer-events: none;"></iframe>
#         </div>
#         <script>
#             document.getElementById("bafgbbijfznowwbwukvl").contentDocument.write(`
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta name="viewport" content="width=device-width, initial-scale=1" />
#     <link
#       href="https://fonts.googleapis.com/css?family=Lato:300,400,400i,700,700i|Playfair+Display:400,700&display=swap"
#       rel="stylesheet"
#     />
#     <link
#       rel="stylesheet"
#       href="https://expose-grapher-state.owid.pages.dev/assets/owid.css"
#     />
#     <style>
#       body { margin: 0; padding: 0; }
#       figure { width: 100%; height: 100%; margin: 0; }
#       .error { color: red; padding: 20px; background: #fee; border-radius: 5px; }
#       /* Hide UI elements for cleaner notebook display */
#       .grapher-share-button, .shareMenuOuter, .GrapherShareMenu,
#       a[data-track-note="chart_click_explore"], .exploreDataButton,
#       .originUrl, .SourcesFooter, .SourcesFooterHTML,
#       .GrapherFooter__sourcesAndLicense { display: none !important; }
#     </style>
#   </head>
#   <body>
#     <figure id="grapher-container"></figure>
#     <script type="module" src="https://expose-grapher-state.owid.pages.dev/assets/owid.mjs"><\/script>
#     <script type="module">
#       await new Promise((resolve) => setTimeout(resolve, 500));
#
#       const { Grapher, GrapherState, OwidTable, React, createRoot } = window;
#       const container = document.getElementById("grapher-container");
#
#       if (!GrapherState || !OwidTable || !React || !createRoot) {
#         container.innerHTML = '<div class="error">Required exports not available. Check console.</div>';
#         throw new Error("Required exports not available");
#       }
#
#       const csvData = \`gdp_per_capita,life_expectancy,entityName,year
# 5000,65,Australia,2020
# 15000,72,Australia,2021
# 25000,78,Australia,2022
# 35000,81,Australia,2023
# 45000,83,Australia,2024
# 8000,68,Australia,2020
# 18000,74,New Zealand,2020
# 28000,79,New Zealand,2021
# 38000,82,New Zealand,2022
# 6000,66,New Zealand,2023
# 12000,70,New Zealand,2024
# 20000,76,New Zealand,2020
# 30000,80,Japan,2020
# 40000,81,Japan,2021
# 7000,67,Japan,2022
# 16000,73,Japan,2023
# 24000,77,Japan,2024
# 32000,80,Japan,2020
# \`;
#       const columnDefs = [{"slug": "gdp_per_capita", "type": "Numeric"}, {"slug": "life_expectancy", "type": "Numeric"}];
#       const table = new OwidTable(csvData, columnDefs);
#
#       const grapherState = new GrapherState({
#         table: table,
#         ...{"hideLogo": true, "selectedEntityNames": [], "chartTypes": ["ScatterPlot"], "ySlugs": "life_expectancy", "xSlug": "gdp_per_capita", "title": "GDP per Capita vs Life Expectancy", "subtitle": "Each point represents a different time period", "sourceDesc": "Sample data", "tab": "chart", "stackMode": "absolute", "minTime": "latest", "hideRelativeToggle": true, "hideEntityControls": true, "matchingEntitiesOnly": false},
#         isConfigReady: true,
#         isDataReady: true,
#       });
#
#       const reactRoot = createRoot(container);
#       reactRoot.render(React.createElement(Grapher, { grapherState }));
#     <\/script>
#   </body>
# </html>
# `);
#             document.getElementById("bafgbbijfznowwbwukvl").contentDocument.close();
#             // Enable interaction on click (wrapper captures click), disable on mouse leave
#             document.getElementById("bafgbbijfznowwbwukvl_wrapper").addEventListener("click", function() {
#                 document.getElementById("bafgbbijfznowwbwukvl").style.pointerEvents = "auto";
#             });
#             document.getElementById("bafgbbijfznowwbwukvl").addEventListener("mouseleave", function() {
#                 this.style.pointerEvents = "none";
#             });
#         </script>

# %% [markdown]
# ## 2. Real-World Example: Life Expectancy vs GDP
#
# Let's recreate an actual OWID chart using real data. This example shows the full power of the library with color encoding, size encoding, log scales, and interactive controls.
#
# Original chart: https://ourworldindata.org/grapher/life-expectancy-un-vs-gdp-per-capita-wb

# %%
# Fetch data directly from OWID's CSV endpoint
df_real = pd.read_csv(
    "https://ourworldindata.org/grapher/life-expectancy-un-vs-gdp-per-capita-wb.csv?useColumnShortNames=true"
)

# Rename columns for consistency
df_real = df_real.rename(columns={'Entity': 'entity', 'Year': 'year'})

# CSV has region info only for last year, propagate it to all rows
df_real['owid_region'] = df_real.entity.map(
    df_real.dropna(subset='owid_region').set_index('entity')['owid_region']
).values

print(f"Loaded {len(df_real):,} rows of data")
df_real.head()
# Out:
# Loaded 59,664 rows of data
#         entity Code  year  life_expectancy__sex_all__age_0__variant_estimates  \
# 0  Afghanistan  AFG  1950                                             28.156
# 1  Afghanistan  AFG  1951                                             28.584
# 2  Afghanistan  AFG  1952                                             29.014
# 3  Afghanistan  AFG  1953                                             29.452
# 4  Afghanistan  AFG  1954                                             29.698
#
#    ny_gdp_pcap_pp_kd  population_historical owid_region
# 0                NaN              7776180.0        Asia
# 1                NaN              7879343.0        Asia
# 2                NaN              7987784.0        Asia
# 3                NaN              8096703.0        Asia
# 4                NaN              8207954.0        Asia

# %%
# Create a fully-featured scatter plot
Chart(df_real).mark_scatter().encode(
    x="ny_gdp_pcap_pp_kd",
    y="life_expectancy__sex_all__age_0__variant_estimates",
    entity="entity",
    color="owid_region",      # Color by region
    size="population_historical"  # Size by population
).label(
    title="Life Expectancy vs GDP per Capita",
    source_desc="UN World Population Prospects; World Bank"
).xaxis(
    label="GDP per Capita (constant 2015 US$)",
    unit="$",
    scale="log",              # Logarithmic scale
    scale_control=True        # Allow user to toggle log/linear
).yaxis(
    label="Life Expectancy (years)",
    unit="years"
).filter(
    matching_entities_only=True  # Only show entities with both variables
).interact(
    entity_control=True       # Enable country picker
)
# Out:
#         <div id="mmqfazudjdazwhawsmow_wrapper" style="position: relative; width: 100%; height: 600px;">
#             <iframe id="mmqfazudjdazwhawsmow" style="width: 100%; height: 100%; border: 0px none; pointer-events: none;"></iframe>
#         </div>
#         <script>
#             document.getElementById("mmqfazudjdazwhawsmow").contentDocument.write(`
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta name="viewport" content="width=device-width, initial-scale=1" />
#     <link
#       href="https://fonts.googleapis.com/css?family=Lato:300,400,400i,700,700i|Playfair+Display:400,700&display=swap"
#       rel="stylesheet"
#     />
#     <link
#       rel="stylesheet"
#       href="https://expose-grapher-state.owid.pages.dev/assets/owid.css"
#     />
#     <style>
#       body { margin: 0; padding: 0; }
#       figure { width: 100%; height: 100%; margin: 0; }
#       .error { color: red; padding: 20px; background: #fee; border-radius: 5px; }
#       /* Hide UI elements for cleaner notebook display */
#       .grapher-share-button, .shareMenuOuter, .GrapherShareMenu,
#       a[data-track-note="chart_click_explore"], .exploreDataButton,
#       .originUrl, .SourcesFooter, .SourcesFooterHTML,
#       .GrapherFooter__sourcesAndLicense { display: none !important; }
#     </style>
#   </head>
#   <body>
#     <figure id="grapher-container"></figure>
#     <script type="module" src="https://expose-grapher-state.owid.pages.dev/assets/owid.mjs"><\/script>
#     <script type="module">
#       await new Promise((resolve) => setTimeout(resolve, 500));
#
#       const { Grapher, GrapherState, OwidTable, React, createRoot } = window;
#       const container = document.getElementById("grapher-container");
#
#       if (!GrapherState || !OwidTable || !React || !createRoot) {
#         container.innerHTML = '<div class="error">Required exports not available. Check console.</div>';
#         throw new Error("Required exports not available");
#       }
#
#       const csvData = \`entityName,Code,year,life_expectancy__sex_all__age_0__variant_estimates,ny_gdp_pcap_pp_kd,population_historical,owid_region
# Afghanistan,AFG,1950,28.156,,7776180.0,Asia
# Afghanistan,AFG,1951,28.584,,7879343.0,Asia
# Afghanistan,AFG,1952,29.014,,7987784.0,Asia
# Afghanistan,AFG,1953,29.452,,8096703.0,Asia
# Afghanistan,AFG,1954,29.698,,8207954.0,Asia
# Afghanistan,AFG,1955,30.366,,8326981.0,Asia
# Afghanistan,AFG,1956,30.83,,8454303.0,Asia
# Afghanistan,AFG,1957,31.345,,8588340.0,Asia
# Afghanistan,AFG,1958,31.84,,8723412.0,Asia
# Afghanistan,AFG,1959,32.337,,8869270.0,Asia
# Afghanistan,AFG,1960,32.799,,9035048.0,Asia
# Afghanistan,AFG,1961,33.291,,9214082.0,Asia
# Afghanistan,AFG,1962,33.757,,9404410.0,Asia
# Afghanistan,AFG,1963,34.201,,9604491.0,Asia
# Afghanistan,AFG,1964,34.673,,9814317.0,Asia
# Afghanistan,AFG,1965,35.124,,10036003.0,Asia
# Afghanistan,AFG,1966,35.583,,10266397.0,Asia
# Afghanistan,AFG,1967,36.042,,10505961.0,Asia
# Afghanistan,AFG,1968,36.51,,10756924.0,Asia
# Afghanistan,AFG,1969,36.979,,11017417.0,Asia
# Afghanistan,AFG,1970,37.46,,11290134.0,Asia
# Afghanistan,AFG,1971,37.932,,11567672.0,Asia
# Afghanistan,AFG,1972,38.423,,11853698.0,Asia
# Afghanistan,AFG,1973,38.951,,12158000.0,Asia
# Afghanistan,AFG,1974,39.469,,12469127.0,Asia
# Afghanistan,AFG,1975,39.994,,12773966.0,Asia
# Afghanistan,AFG,1976,40.518,,13059861.0,Asia
# Afghanistan,AFG,1977,41.082,,13340758.0,Asia
# Afghanistan,AFG,1978,40.086,,13611444.0,Asia
# Afghanistan,AFG,1979,38.844,,13655575.0,Asia
# Afghanistan,AFG,1980,39.258,,13169313.0,Asia
# Afghanistan,AFG,1981,39.406,,11937586.0,Asia
# Afghanistan,AFG,1982,36.058,,10991380.0,Asia
# Afghanistan,AFG,1983,36.517,,10917985.0,Asia
# Afghanistan,AFG,1984,31.473,,11190222.0,Asia
# Afghanistan,AFG,1985,32.132,,11426855.0,Asia
# Afghanistan,AFG,1986,38.4,,11420074.0,Asia
# Afghanistan,AFG,1987,38.831,,11387822.0,Asia
# Afghanistan,AFG,1988,43.238,,11523299.0,Asia
# Afghanistan,AFG,1989,44.496,,11874089.0,Asia
# Afghanistan,AFG,1990,45.118,,12045664.0,Asia
# Afghanistan,AFG,1991,45.521,,12238879.0,Asia
# Afghanistan,AFG,1992,46.569,,13278983.0,Asia
# Afghanistan,AFG,1993,51.021,,14943175.0,Asia
# Afghanistan,AFG,1994,50.969,,16250800.0,Asia
# Afghanistan,AFG,1995,52.103,,17065837.0,Asia
# Afghanistan,AFG,1996,52.83,,17763266.0,Asia
# Afghanistan,AFG,1997,53.212,,18452100.0,Asia
# Afghanistan,AFG,1998,52.487,,19159996.0,Asia
# Afghanistan,AFG,1999,54.532,,19887792.0,Asia
# Afghanistan,AFG,2000,55.005,1617.8264,20130334.0,Asia
# Afghanistan,AFG,2001,55.511,1454.1108,20284303.0,Asia
# Afghanistan,AFG,2002,56.225,1774.3087,21378123.0,Asia
# Afghanistan,AFG,2003,57.171,1815.9282,22733053.0,Asia
# Afghanistan,AFG,2004,57.81,1776.9182,23560656.0,Asia
# Afghanistan,AFG,2005,58.247,1908.1147,24404575.0,Asia
# Afghanistan,AFG,2006,58.553,1929.7239,25424100.0,Asia
# Afghanistan,AFG,2007,58.956,2155.353,25909852.0,Asia
# Afghanistan,AFG,2008,59.708,2191.5044,26482631.0,Asia
# Afghanistan,AFG,2009,60.248,2565.022,27466102.0,Asia
# Afghanistan,AFG,2010,60.702,2848.5862,28284088.0,Asia
# Afghanistan,AFG,2011,61.25,2757.0525,29347708.0,Asia
# Afghanistan,AFG,2012,61.735,2985.319,30560036.0,Asia
# Afghanistan,AFG,2013,62.188,3046.5798,31622709.0,Asia
# Afghanistan,AFG,2014,62.26,3017.9426,32792528.0,Asia
# Afghanistan,AFG,2015,62.27,2967.6921,33831767.0,Asia
# Afghanistan,AFG,2016,62.646,2958.7854,34700613.0,Asia
# Afghanistan,AFG,2017,62.406,2952.999,35688941.0,Asia
# Afghanistan,AFG,2018,62.443,2902.392,36743040.0,Asia
# Afghanistan,AFG,2019,62.941,2927.245,37856125.0,Asia
# Afghanistan,AFG,2020,61.454,2769.6858,39068977.0,Asia
# Afghanistan,AFG,2021,60.417,2144.1665,40000410.0,Asia
# Afghanistan,AFG,2022,65.617,1981.7102,40578847.0,Asia
# Afghanistan,AFG,2023,66.035,1983.8126,41454762.0,Asia
# Afghanistan,AFG,-10000,,,14737.0,Asia
# Afghanistan,AFG,-9000,,,20405.0,Asia
# Afghanistan,AFG,-8000,,,28253.0,Asia
# Afghanistan,AFG,-7000,,,39120.0,Asia
# Afghanistan,AFG,-6000,,,54166.0,Asia
# Afghanistan,AFG,-5000,,,75000.0,Asia
# Afghanistan,AFG,-4000,,,306250.0,Asia
# Afghanistan,AFG,-3000,,,537500.0,Asia
# Afghanistan,AFG,-2000,,,768750.0,Asia
# Afghanistan,AFG,-1000,,,1000000.0,Asia
# Afghanistan,AFG,0,,,2000000.0,Asia
# Afghanistan,AFG,100,,,2250000.0,Asia
# Afghanistan,AFG,200,,,2500000.0,Asia
# Afghanistan,AFG,300,,,2500000.0,Asia
# Afghanistan,AFG,400,,,2500000.0,Asia
# Afghanistan,AFG,500,,,2500000.0,Asia
# Afghanistan,AFG,600,,,2500000.0,Asia
# Afghanistan,AFG,700,,,2425000.0,Asia
# Afghanistan,AFG,800,,,2350000.0,Asia
# Afghanistan,AFG,900,,,2300000.0,Asia
# Afghanistan,AFG,1000,,,2250000.0,Asia
# Afghanistan,AFG,1100,,,2375000.0,Asia
# Afghanistan,AFG,1200,,,2500000.0,Asia
# Afghanistan,AFG,1300,,,1750000.0,Asia
# Afghanistan,AFG,1400,,,1875000.0,Asia
# Afghanistan,AFG,1500,,,2000000.0,Asia
# Afghanistan,AFG,1600,,,2500000.0,Asia
# Afghanistan,AFG,1700,,,2500000.0,Asia
# Afghanistan,AFG,1710,,,2561625.0,Asia
# Afghanistan,AFG,1720,,,2619844.0,Asia
# Afghanistan,AFG,1730,,,2679386.0,Asia
# Afghanistan,AFG,1740,,,2740281.0,Asia
# Afghanistan,AFG,1750,,,2802560.0,Asia
# Afghanistan,AFG,1760,,,2866255.0,Asia
# Afghanistan,AFG,1770,,,2931397.0,Asia
# Afghanistan,AFG,1780,,,2998019.0,Asia
# Afghanistan,AFG,1790,,,3066156.0,Asia
# Afghanistan,AFG,1800,,,3280000.0,Asia
# Afghanistan,AFG,1801,,,3280000.0,Asia
# Afghanistan,AFG,1802,,,3280000.0,Asia
# Afghanistan,AFG,1803,,,3280000.0,Asia
# Afghanistan,AFG,1804,,,3280000.0,Asia
# Afghanistan,AFG,1805,,,3280000.0,Asia
# Afghanistan,AFG,1806,,,3280000.0,Asia
# Afghanistan,AFG,1807,,,3280000.0,Asia
# Afghanistan,AFG,1808,,,3280000.0,Asia
# Afghanistan,AFG,1809,,,3280000.0,Asia
# Afghanistan,AFG,1810,,,3280000.0,Asia
# Afghanistan,AFG,1811,,,3280000.0,Asia
# Afghanistan,AFG,1812,,,3280000.0,Asia
# Afghanistan,AFG,1813,,,3280000.0,Asia
# Afghanistan,AFG,1814,,,3280000.0,Asia
# Afghanistan,AFG,1815,,,3280000.0,Asia
# Afghanistan,AFG,1816,,,3280000.0,Asia
# Afghanistan,AFG,1817,,,3280000.0,Asia
# Afghanistan,AFG,1818,,,3280000.0,Asia
# Afghanistan,AFG,1819,,,3282935.0,Asia
# Afghanistan,AFG,1820,,,3288817.0,Asia
# Afghanistan,AFG,1821,,,3297661.0,Asia
# Afghanistan,AFG,1822,,,3309479.0,Asia
# Afghanistan,AFG,1823,,,3324285.0,Asia
# Afghanistan,AFG,1824,,,3339157.0,Asia
# Afghanistan,AFG,1825,,,3354095.0,Asia
# Afghanistan,AFG,1826,,,3369101.0,Asia
# Afghanistan,AFG,1827,,,3384173

# %% [markdown]
# ### CO2 Emissions with Map View
#
# Another real-world example showing global CO2 emissions over time with interactive map visualization.
#
# Original chart: https://ourworldindata.org/grapher/annual-co2-emissions-per-country

# %%
# Fetch CO2 emissions data from OWID
df_co2 = pd.read_csv(
    "https://ourworldindata.org/grapher/annual-co2-emissions-per-country.csv?useColumnShortNames=true"
)

# Rename columns for consistency
df_co2 = df_co2.rename(columns={'Entity': 'entity', 'Year': 'year'})

print(f"Loaded {len(df_co2):,} rows of CO2 data")
print(f"Time range: {df_co2['year'].min()} to {df_co2['year'].max()}")
df_co2.head()

# %%
# Create line chart with map view for CO2 emissions
Chart(df_co2).mark_line().encode(
    x="year",
    y="emissions_total",
    entity="entity"
).label(
    title="Annual CO₂ emissions",
    subtitle="Carbon dioxide emissions from fossil fuels and industry",
    source_desc="Global Carbon Project"
).yaxis(
    label="CO₂ emissions",
    unit="tonnes"
).select(
    # Pre-select major emitting countries
    entities=["United States", "China", "India", "United Kingdom", "Germany", "France", "Brazil"]
).interact(
    allow_relative=True,    # Allow viewing as relative change
    entity_control=True,    # Enable country picker
    enable_map=True         # Enable map tab (defaults to map view)
)

# %% [markdown]
# ## 3. Interactive Features
#
# OWID charts support various interactive controls that users can toggle.

# %% [markdown]
# ### Entity Picker
#
# Let users select which countries/entities to display.

# %%
Chart(df).mark_line().encode(
    x='year',
    y='population',
    entity='country'
).label(
    title='Population Trends',
    subtitle='Select countries to compare'
).interact(
    entity_control=True
)
# Out:
#         <div id="adsitxzlfcyzsfnrowuf_wrapper" style="position: relative; width: 100%; height: 600px;">
#             <iframe id="adsitxzlfcyzsfnrowuf" style="width: 100%; height: 100%; border: 0px none; pointer-events: none;"></iframe>
#         </div>
#         <script>
#             document.getElementById("adsitxzlfcyzsfnrowuf").contentDocument.write(`
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta name="viewport" content="width=device-width, initial-scale=1" />
#     <link
#       href="https://fonts.googleapis.com/css?family=Lato:300,400,400i,700,700i|Playfair+Display:400,700&display=swap"
#       rel="stylesheet"
#     />
#     <link
#       rel="stylesheet"
#       href="https://expose-grapher-state.owid.pages.dev/assets/owid.css"
#     />
#     <style>
#       body { margin: 0; padding: 0; }
#       figure { width: 100%; height: 100%; margin: 0; }
#       .error { color: red; padding: 20px; background: #fee; border-radius: 5px; }
#       /* Hide UI elements for cleaner notebook display */
#       .grapher-share-button, .shareMenuOuter, .GrapherShareMenu,
#       a[data-track-note="chart_click_explore"], .exploreDataButton,
#       .originUrl, .SourcesFooter, .SourcesFooterHTML,
#       .GrapherFooter__sourcesAndLicense { display: none !important; }
#     </style>
#   </head>
#   <body>
#     <figure id="grapher-container"></figure>
#     <script type="module" src="https://expose-grapher-state.owid.pages.dev/assets/owid.mjs"><\/script>
#     <script type="module">
#       await new Promise((resolve) => setTimeout(resolve, 500));
#
#       const { Grapher, GrapherState, OwidTable, React, createRoot } = window;
#       const container = document.getElementById("grapher-container");
#
#       if (!GrapherState || !OwidTable || !React || !createRoot) {
#         container.innerHTML = '<div class="error">Required exports not available. Check console.</div>';
#         throw new Error("Required exports not available");
#       }
#
#       const csvData = \`year,entityName,population
# 2000,Australia,19.2
# 2005,Australia,20.4
# 2010,Australia,22.0
# 2015,Australia,23.8
# 2020,Australia,25.7
# 2000,New Zealand,3.9
# 2005,New Zealand,4.1
# 2010,New Zealand,4.4
# 2015,New Zealand,4.6
# 2020,New Zealand,5.1
# 2000,Japan,126.8
# 2005,Japan,127.8
# 2010,Japan,128.1
# 2015,Japan,127.1
# 2020,Japan,125.8
# \`;
#       const columnDefs = [{"slug": "population", "type": "Numeric"}];
#       const table = new OwidTable(csvData, columnDefs);
#
#       const grapherState = new GrapherState({
#         table: table,
#         ...{"hideLogo": true, "selectedEntityNames": ["Australia", "New Zealand", "Japan"], "chartTypes": ["LineChart"], "ySlugs": "population", "title": "Population Trends", "subtitle": "Select countries to compare", "tab": "chart", "stackMode": "absolute", "hideRelativeToggle": true, "hideEntityControls": false, "matchingEntitiesOnly": false},
#         isConfigReady: true,
#         isDataReady: true,
#       });
#
#       const reactRoot = createRoot(container);
#       reactRoot.render(React.createElement(Grapher, { grapherState }));
#     <\/script>
#   </body>
# </html>
# `);
#             document.getElementById("adsitxzlfcyzsfnrowuf").contentDocument.close();
#             // Enable interaction on click (wrapper captures click), disable on mouse leave
#             document.getElementById("adsitxzlfcyzsfnrowuf_wrapper").addEventListener("click", function() {
#                 document.getElementById("adsitxzlfcyzsfnrowuf").style.pointerEvents = "auto";
#             });
#             document.getElementById("adsitxzlfcyzsfnrowuf").addEventListener("mouseleave", function() {
#                 this.style.pointerEvents = "none";
#             });
#         </script>

# %% [markdown]
# ### Map View
#
# For geographic data, enable the map tab.

# %%
Chart(df).mark_line().encode(
    x='year',
    y='population',
    entity='country'
).label(title='Population by Country').interact(
    enable_map=True  # Defaults to map tab
)
# Out:
#         <div id="uortajsaftdsmxjyelim_wrapper" style="position: relative; width: 100%; height: 600px;">
#             <iframe id="uortajsaftdsmxjyelim" style="width: 100%; height: 100%; border: 0px none; pointer-events: none;"></iframe>
#         </div>
#         <script>
#             document.getElementById("uortajsaftdsmxjyelim").contentDocument.write(`
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta name="viewport" content="width=device-width, initial-scale=1" />
#     <link
#       href="https://fonts.googleapis.com/css?family=Lato:300,400,400i,700,700i|Playfair+Display:400,700&display=swap"
#       rel="stylesheet"
#     />
#     <link
#       rel="stylesheet"
#       href="https://expose-grapher-state.owid.pages.dev/assets/owid.css"
#     />
#     <style>
#       body { margin: 0; padding: 0; }
#       figure { width: 100%; height: 100%; margin: 0; }
#       .error { color: red; padding: 20px; background: #fee; border-radius: 5px; }
#       /* Hide UI elements for cleaner notebook display */
#       .grapher-share-button, .shareMenuOuter, .GrapherShareMenu,
#       a[data-track-note="chart_click_explore"], .exploreDataButton,
#       .originUrl, .SourcesFooter, .SourcesFooterHTML,
#       .GrapherFooter__sourcesAndLicense { display: none !important; }
#     </style>
#   </head>
#   <body>
#     <figure id="grapher-container"></figure>
#     <script type="module" src="https://expose-grapher-state.owid.pages.dev/assets/owid.mjs"><\/script>
#     <script type="module">
#       await new Promise((resolve) => setTimeout(resolve, 500));
#
#       const { Grapher, GrapherState, OwidTable, React, createRoot } = window;
#       const container = document.getElementById("grapher-container");
#
#       if (!GrapherState || !OwidTable || !React || !createRoot) {
#         container.innerHTML = '<div class="error">Required exports not available. Check console.</div>';
#         throw new Error("Required exports not available");
#       }
#
#       const csvData = \`year,entityName,population
# 2000,Australia,19.2
# 2005,Australia,20.4
# 2010,Australia,22.0
# 2015,Australia,23.8
# 2020,Australia,25.7
# 2000,New Zealand,3.9
# 2005,New Zealand,4.1
# 2010,New Zealand,4.4
# 2015,New Zealand,4.6
# 2020,New Zealand,5.1
# 2000,Japan,126.8
# 2005,Japan,127.8
# 2010,Japan,128.1
# 2015,Japan,127.1
# 2020,Japan,125.8
# \`;
#       const columnDefs = [{"slug": "population", "type": "Numeric"}];
#       const table = new OwidTable(csvData, columnDefs);
#
#       const grapherState = new GrapherState({
#         table: table,
#         ...{"hideLogo": true, "selectedEntityNames": ["Australia", "New Zealand", "Japan"], "chartTypes": ["LineChart"], "ySlugs": "population", "title": "Population by Country", "hasMapTab": true, "tab": "map", "stackMode": "absolute", "hideRelativeToggle": true, "hideEntityControls": true, "matchingEntitiesOnly": false},
#         isConfigReady: true,
#         isDataReady: true,
#       });
#
#       const reactRoot = createRoot(container);
#       reactRoot.render(React.createElement(Grapher, { grapherState }));
#     <\/script>
#   </body>
# </html>
# `);
#             document.getElementById("uortajsaftdsmxjyelim").contentDocument.close();
#             // Enable interaction on click (wrapper captures click), disable on mouse leave
#             document.getElementById("uortajsaftdsmxjyelim_wrapper").addEventListener("click", function() {
#                 document.getElementById("uortajsaftdsmxjyelim").style.pointerEvents = "auto";
#             });
#             document.getElementById("uortajsaftdsmxjyelim").addEventListener("mouseleave", function() {
#                 this.style.pointerEvents = "none";
#             });
#         </script>

# %% [markdown]
# ## 4. Export Configuration
#
# For advanced users: view the underlying JSON configuration that gets sent to the OWID Grapher.

# %%
chart = Chart(df).mark_line().encode(
    x='year',
    y='population',
    entity='country'
).label(title='Population Over Time')

# Export the configuration
chart.export()
# Out:
# {'tab': 'chart',
#  'title': 'Population Over Time',
#  'subtitle': '',
#  'note': '',
#  'sourceDesc': '',
#  'hideLogo': True,
#  'isPublished': True,
#  'type': 'LineChart',
#  'hideTitleAnnotation': False,
#  'hideLegend': False,
#  'hideEntityControls': True,
#  'hideRelativeToggle': True,
#  'hasMapTab': False,
#  'stackMode': 'absolute',
#  'matchingEntitiesOnly': False,
#  'xAxis': {},
#  'yAxis': {},
#  'selectedEntityNames': ['Australia', 'New Zealand', 'Japan'],
#  'owidDataset': {'data': {'year': [2000,
#     2005,
#     2010,
#     2015,
#     2020,
#     2000,
#     2005,
#     2010,
#     2015,
#     2020,
#     2000,
#     2005,
#     2010,
#     2015,
#     2020],
#    'entityName': ['Australia',
#     'Australia',
#     'Australia',
#     'Australia',
#     'Australia',
#     'New Zealand',
#     'New Zealand',
#     'New Zealand',
#     'New Zealand',
#     'New Zealand',
#     'Japan',
#     'Japan',
#     'Japan',
#     'Japan',
#     'Japan'],
#    'population': [19.2,
#     20.4,
#     22.0,
#     23.8,
#     25.7,
#     3.9,
#     4.1,
#     4.4,
#     4.6,
#     5.1,
#     126.8,
#     127.8,
#     128.1,
#     127.1,
#     125.8]},
#   'metadata': {'population': {'display': {}}}},
#  'dimensions': [{'property': 'y',
#    'variableName': 'population',
#    'display': {}}],
#  'chartTypes': ['LineChart']}

# %% [markdown]
# ## Next Steps
#
# Check out the [README](https://github.com/owid/owid-grapher-py) for more examples and documentation:
#
# - Stacked bar charts
# - Custom axis configuration
# - Data selection and filtering
# - Relative mode transformations
#
# Explore more OWID charts at [ourworldindata.org](https://ourworldindata.org)
